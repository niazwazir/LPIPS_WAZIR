# %% [markdown]
# STEP-1: TO CREATE A PATCH FROM DIFFERENT IMAGES

# %%
# !git clone https://github.com/niazwazir/LPIPS_WAZIR.git
# Out:
# Cloning into 'LPIPS_WAZIR'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 68 (delta 23), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (68/68), 11.21 MiB | 6.26 MiB/s, done.

# %%
# !ls
# Out:
# LPIPS_WAZIR  sample_data

# %%
cd LPIPS_WAZIR
# Out:
# /content/LPIPS_WAZIR

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 LPIPS.ipynb   SET5   SRCNN

# %%
# !pip install split-image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from split_image import split_image

# %%
cd SET5
# Out:
# /content/LPIPS_WAZIR/SET5

# %%
# !ls
# Out:
# butterfly_GT.bmp

# %%
# !split-image butterfly_GT.bmp 2 2
# Out:
# Exporting image tile: ./butterfly_GT_0.bmp
# Exporting image tile: ./butterfly_GT_1.bmp
# Exporting image tile: ./butterfly_GT_2.bmp
# Exporting image tile: ./butterfly_GT_3.bmp
# Done!

# %%
# !ls
# Out:
# butterfly_GT_0.bmp  butterfly_GT_2.bmp	butterfly_GT.bmp
# butterfly_GT_1.bmp  butterfly_GT_3.bmp

# %%
# !rm butterfly_GT.bmp

# %%
# !ls
# Out:
# butterfly_GT_0.bmp  butterfly_GT_1.bmp	butterfly_GT_2.bmp  butterfly_GT_3.bmp

# %%
cd ..
# Out:
# /content/LPIPS_WAZIR

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 LPIPS.ipynb   SET5   SRCNN

# %%
cd SRCNN
# Out:
# /content/LPIPS_WAZIR/SRCNN

# %%
# !ls
# Out:
# butterfly_GT_srcnn_x4.bmp

# %%
# !split-image butterfly_GT_srcnn_x4.bmp 2 2
# Out:
# Exporting image tile: ./butterfly_GT_srcnn_x4_0.bmp
# Exporting image tile: ./butterfly_GT_srcnn_x4_1.bmp
# Exporting image tile: ./butterfly_GT_srcnn_x4_2.bmp
# Exporting image tile: ./butterfly_GT_srcnn_x4_3.bmp
# Done!

# %%
# !ls
# Out:
# butterfly_GT_srcnn_x4_0.bmp  butterfly_GT_srcnn_x4_3.bmp
# butterfly_GT_srcnn_x4_1.bmp  butterfly_GT_srcnn_x4.bmp
# butterfly_GT_srcnn_x4_2.bmp

# %%
# !rm butterfly_GT_srcnn_x4.bmp

# %%
# !ls
# Out:
# butterfly_GT_srcnn_x4_0.bmp  butterfly_GT_srcnn_x4_2.bmp
# butterfly_GT_srcnn_x4_1.bmp  butterfly_GT_srcnn_x4_3.bmp

# %%
cd ..
# Out:
# /content/LPIPS_WAZIR

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 LPIPS.ipynb   SET5   SRCNN

# %%
from PIL import Image
import os, sys

# %%
path = "SET5/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((64, 64), Image.ANTIALIAS)
            imResize.save(f + 'resized.png', quality=90)

resize()

# %%
import glob, os
files = glob.glob('SET5/*.bmp')
for file in files:
    os.remove(file)

# %%
path = "SRCNN/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((64, 64), Image.ANTIALIAS)
            imResize.save(f + 'resized.png', quality=90)

resize()

# %%
import glob, os
files = glob.glob('SRCNN/*.bmp')
for file in files:
    os.remove(file)

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 LPIPS.ipynb   SET5   SRCNN

# %%
# !git clone https://github.com/richzhang/PerceptualSimilarity
# Out:
# Cloning into 'PerceptualSimilarity'...
# remote: Enumerating objects: 778, done.
# remote: Counting objects: 100% (775/775), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 778 (delta 457), reused 774 (delta 456), pack-reused 3
# Receiving objects: 100% (778/778), 8.75 MiB | 23.04 MiB/s, done.
# Resolving deltas: 100% (457/457), done.

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 PerceptualSimilarity   SRCNN
#  LPIPS.ipynb					 SET5

# %%
from distutils.dir_util import copy_tree
copy_tree("SET5", "PerceptualSimilarity/imgs/ex_dir0")
# Out:
# ['PerceptualSimilarity/imgs/ex_dir0/butterfly_GT_1resized.png',
#  'PerceptualSimilarity/imgs/ex_dir0/butterfly_GT_2resized.png',
#  'PerceptualSimilarity/imgs/ex_dir0/butterfly_GT_3resized.png',
#  'PerceptualSimilarity/imgs/ex_dir0/butterfly_GT_0resized.png']

# %%
from distutils.dir_util import copy_tree
copy_tree("SRCNN", "PerceptualSimilarity/imgs/ex_dir1")
# Out:
# ['PerceptualSimilarity/imgs/ex_dir1/butterfly_GT_srcnn_x4_2resized.png',
#  'PerceptualSimilarity/imgs/ex_dir1/butterfly_GT_srcnn_x4_3resized.png',
#  'PerceptualSimilarity/imgs/ex_dir1/butterfly_GT_srcnn_x4_1resized.png',
#  'PerceptualSimilarity/imgs/ex_dir1/butterfly_GT_srcnn_x4_0resized.png']

# %%
# !ls
# Out:
# 'LPIPS_DEEP LEARNING METHOD FOR ENHANCING.png'	 PerceptualSimilarity   SRCNN
#  LPIPS.ipynb					 SET5

# %%
cd PerceptualSimilarity/
# Out:
# /content/LPIPS_WAZIR/PerceptualSimilarity

# %%
# !ls
# Out:
# data	    lpips_1dir_allpairs.py  requirements.txt	   train.py
# Dockerfile  lpips_2dirs.py	    scripts		   util
# imgs	    lpips_2imgs.py	    setup.py
# LICENSE     lpips_loss.py	    test_dataset_model.py
# lpips	    README.md		    test_network.py

# %%
# !pip install lpips
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !ls
# Out:
# data	    lpips_1dir_allpairs.py  requirements.txt	   train.py
# Dockerfile  lpips_2dirs.py	    scripts		   util
# imgs	    lpips_2imgs.py	    setup.py
# LICENSE     lpips_loss.py	    test_dataset_model.py
# lpips	    README.md		    test_network.py

# %%
import lpips
loss_fn_alex = lpips.LPIPS(net='alex') # best forward scores
loss_fn_vgg = lpips.LPIPS(net='vgg') # closer to "traditional" perceptual loss, when used for optimization

import torch
img0 = torch.zeros(1,3,64,64) # image should be RGB, IMPORTANT: normalized to [-1,1]
img1 = torch.zeros(1,3,64,64)
d = loss_fn_alex(img0, img1)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 185MB/s]
# Loading model from: /content/LPIPS_WAZIR/PerceptualSimilarity/lpips/weights/v0.1/alex.pth
# ...

# %%
#CALCULATE LPIPS OF SINGLE IMAGE
# !python lpips_2imgs.py -p0 imgs/ex_dir0/butterfly_GT_1resized.png -p1 imgs/ex_dir1/butterfly_GT_srcnn_x4_1resized.png --use_gpu
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /content/LPIPS_WAZIR/PerceptualSimilarity/lpips/weights/v0.1/alex.pth
# Distance: 0.016

# %%
# !ls
# Out:
# data	    lpips_1dir_allpairs.py  requirements.txt	   train.py
# Dockerfile  lpips_2dirs.py	    scripts		   util
# imgs	    lpips_2imgs.py	    setup.py
# LICENSE     lpips_loss.py	    test_dataset_model.py
# lpips	    README.md		    test_network.py

# %%
#CALCULATE LPIPS OF MORE IMAGES IN A FOLDER
#!python lpips_2dirs.py -d0 imgs/ex_dir0/ -d1 imgs/ex_dir1 -o imgs/example_dists.txt --use_gpu

# %%
# !ls
# Out:
# data	    lpips_1dir_allpairs.py  requirements.txt	   train.py
# Dockerfile  lpips_2dirs.py	    scripts		   util
# imgs	    lpips_2imgs.py	    setup.py
# LICENSE     lpips_loss.py	    test_dataset_model.py
# lpips	    README.md		    test_network.py

# %%
cd imgs
# Out:
# /content/LPIPS_WAZIR/PerceptualSimilarity/imgs

# %%
# !ls
# Out:
# ex_dir0  ex_dir1  ex_dir_pair  ex_p0.png  ex_p1.png  ex_ref.png  fig1.png

# %%
cd ex_dir0
# Out:
# /content/LPIPS_WAZIR/PerceptualSimilarity/imgs/ex_dir0

# %%
# !ls
# Out:
# 0.png  butterfly_GT_0resized.png  butterfly_GT_2resized.png
# 1.png  butterfly_GT_1resized.png  butterfly_GT_3resized.png

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
#HOW MANY IMAGES WANT TO DISPLAY
NUM_ROWS = 2
IMGs_IN_ROW = 2

# %%
images = []
for img_path in glob.glob('*.png'):
    images.append(mpimg.imread(img_path))
f, ax_arr = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(12,16))

for j, row in enumerate(ax_arr):
    for i, ax in enumerate(row):
        ax.imshow(images[j*IMGs_IN_ROW+i])
        ax.set_title(f'image {j*IMGs_IN_ROW+i+1}')
plt.show()

# %%
# !ls
# Out:
# 0.png  butterfly_GT_0resized.png  butterfly_GT_2resized.png
# 1.png  butterfly_GT_1resized.png  butterfly_GT_3resized.png

# %%
cd ..
# Out:
# /content/LPIPS_WAZIR/PerceptualSimilarity/imgs

# %%
# !ls
# Out:
# ex_dir0  ex_dir1  ex_dir_pair  ex_p0.png  ex_p1.png  ex_ref.png  fig1.png

# %%
cd ex_dir1
# Out:
# /content/LPIPS_WAZIR/PerceptualSimilarity/imgs/ex_dir1

# %%
images = []
for img_path in glob.glob('*.png'):
    images.append(mpimg.imread(img_path))
f, ax_arr = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(12,16))

for j, row in enumerate(ax_arr):
    for i, ax in enumerate(row):
        ax.imshow(images[j*IMGs_IN_ROW+i])
        ax.set_title(f'image {j*IMGs_IN_ROW+i+1}')
plt.show()
